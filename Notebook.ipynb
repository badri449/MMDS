# %% [markdown]
# ##**Mining Massive Datasets Final Project**

# %% [markdown]
# **Group Member 1:** Mateo Castro (mc7212) **Group Member 2:** Badrinath Gujjula (bg2310) **Group Member 3:** Yuqi Liu (yl8406)

# %%
import os
import json
import gzip
import pandas as pd
import numpy as np
from urllib.request import urlopen

# %% [markdown]
# ## Dataset Description
# The dataset used in this project is the Magazine Subscriptions set in Amazon review data, which is downloaded from http://deepyeti.ucsd.edu/jianmo/amazon/. The Magazine Subscriptions set contians a ratings set and a meta data set. The ratings dataset has 3 columns and 89689 rows. The rating set has three columns: Product_ID, Customer_ID, and Rating, and each row corresponds to a rating record. The meta data has 19 columns and 2320 unique rows. Each row contains the information of one item, and each column corresponds to one feature. The features we mainly used in meta data set are description, category, and brand.

# %% [markdown]
# ## Download Ratings Dataset

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/Magazine_Subscriptions.csv
# Out:
# --2022-05-09 17:21:30--  http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/Magazine_Subscriptions.csv
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3743304 (3.6M) [application/octet-stream]
# Saving to: ‘Magazine_Subscriptions.csv’
#
# Magazine_Subscripti 100%[===================>]   3.57M  2.95MB/s    in 1.2s
#
# 2022-05-09 17:21:32 (2.95 MB/s) - ‘Magazine_Subscriptions.csv’ saved [3743304/3743304]

# %%
### Load the csv
df = pd.read_csv('Magazine_Subscriptions.csv', usecols=[i for i in range(3)], names=['Product_ID', 'Customer_ID', 'Rating'])

# Display first 5 lines of the DataFrame
df.head()
# Out:
#    Product_ID     Customer_ID  Rating
# 0  B00005N7P0   AH2IFH762VY5U     5.0
# 1  B00005N7P0   AOSFI0JEYU4XM     5.0
# 2  B00005N7OJ  A3JPFWKS83R49V     3.0
# 3  B00005N7OJ  A19FKU6JZQ2ECJ     5.0
# 4  B00005N7P0  A25MDGOMZ2GALN     5.0

# %% [markdown]
# ## Download Meta data for products

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_Magazine_Subscriptions.json.gz
# Out:
# --2022-05-09 17:21:32--  http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_Magazine_Subscriptions.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1276947 (1.2M) [application/octet-stream]
# Saving to: ‘meta_Magazine_Subscriptions.json.gz’
#
# meta_Magazine_Subsc 100%[===================>]   1.22M  1.33MB/s    in 0.9s
#
# 2022-05-09 17:21:34 (1.33 MB/s) - ‘meta_Magazine_Subscriptions.json.gz’ saved [1276947/1276947]

# %%
### load the meta data

data = []
with gzip.open('meta_Magazine_Subscriptions.json.gz') as f:
  try:
    for l in f:
        data.append(json.loads(l.strip()))
  except:
    print("Done with error")
    
# total length of list, this number equals total number of products
print(len(data))

# first row of the list
print(data[0])
# Out:
# 3385
# {'category': ['Magazine Subscriptions', 'Professional & Educational Journals', 'Professional & Trade', 'Humanities & Social Sciences', 'Economics & Economic Theory'], 'tech1': '', 'description': ['REASON is edited for people interested in economic, social, and international issues. Viewpoint stresses individual liberty, private responsibility, and limited government. Some emphasis on Pacific Rim, local/state issues with national impact, science/technology. Regular departments include news/trends, book reviews (mostly history, politics, and economics), and cultural commentary.'], 'fit': '', 'title': '<span class="a-size-medium a-color-secondary"', 'also_buy': ['B002PXVYLE',
jpg', 'https://images-na.ssl-images-amazon.com/images/I/61X7QXE5XYL._SX38_SY50_CR,0,0,38,50_.jpg'], 'imageURLHighRes': ['https://images-na.ssl-images-amazon.com/images/I/51Iph04Jy3L.jpg', 'https://images-na.ssl-images-amazon.com/images/I/51se%2BqMOjGL.jpg', 'https://images-na.ssl-images-amazon.com/images/I/518DJV6YPSL.jpg', 'https://images-na.ssl-images-amazon.com/images/I/61NXTT9F6XL.jpg', 'https://images-na.ssl-images-amazon.com/images/I/518CWA373QL.jpg', 'https://images-na.ssl-images-amazon.com/images/I/61X7QXE5XYL.jpg']}

# %%
# convert list into pandas dataframe

df_meta = pd.DataFrame.from_dict(data)

print(len(df_meta))
# Out:
# 3385

# %%
df_meta.head()
# Out:
#                                             category tech1  \
# 0  [Magazine Subscriptions, Professional & Educat...
# 1  [Magazine Subscriptions, Arts, Music &amp; Pho...
# 2  [Magazine Subscriptions, Fashion &amp; Style, ...
# 3  [Magazine Subscriptions, Sports, Recreation & ...
# 4  [Magazine Subscriptions, Professional & Educat...
#
#                                          description fit  \
# 0  [REASON is edited for people interested in eco...
# 1  [Written by and for musicians. Covers a variet...
# 2  [Allure is the beauty expert. Every issue is f...
# 3  [FLIGHT JOURNAL includes articles on aviation ...
# 4  [RIDER is published for the road and street ri...
#
#                                            title  \
# 0  <span class="a-size-medium a-color-secondary"
# 1  <span class="a-size-medium a-color-secondary"
# 2  <span class="a-size-medium a-color-secondary"
# 3  <span class="a-size-medium a-color-secondary"
# 4  <span class="a-size-medium a-color-secondary"
#
#                                             also_buy tech2  \
# 0  [B002PXVYLE, B01MCU84LB, B000UHI2LW, B01AKS14A...
# 1  [B002PXVYGE, B0054LRNC8, B000BVEELE, B00006KC3...
# 2  [B001THPA4O, B002PXVZWW, B001THPA1M, B001THPA1...
# 3  [B07JVF7QW4, B00ATQ6FPY, B002G551F6, B00008CGW...
# 4  [B002PXVYD2, B01BM7TOU6, B000060MKJ, B000BNNIG...
#
#                                brand feature                             rank  \
# 0                    Reason Magazine      []                               []
# 1           String Letter Publishers      []  742 in Magazine Subscriptions (
# 2            Conde Nast Publications      []                               []
# 3                  AirAge Publishing      []                               []
# 4  EPG Media & Specialty Information      []                               []
#
#                                            also_view  \
# 0  [B002PXVYLE, B000UHI2LW, B01MCU84LB, B002PXW18...
# 1  [B002PXVYGE, B0054LRNC8, B00006L16A, 171906487...
# 2  [B002PXVZWW, B001THPA4O, B001THPA1M, B01N819UD...
# 3  [B002G551F6, B00ATQ6FPY, B00005N7PT, B001THPA2...
# 4  [B01BM7TOU6, B000060MKJ, B002PXVYD2, B000BNNIG...
#
#                                              details                main_cat  \
# 0  {'Format:': 'Print Magazine', 'Shipping: ': 'C...  Magazine Subscriptions
# 1  {'Format:': 'Print Magazine', 'Shipping: ': 'C...  Magazine Subscriptions
# 2  {'Format:': 'Print Magazine', 'Shipping: ': 'C...  Magazine Subscriptions
# 3  {'Format:': 'Print Magazine', 'Shipping: ': 'C...  Magazine Subscriptions
# 4  {'Format:': 'Print Magazine', 'Shipping: ': 'C...  Magazine Subscriptions
#
#   similar_item date price        asin  \
# 0                          B00005N7NQ
# 1                          B00005N7OC
# 2                          B00005N7OD
# 3                          B00005N7O9
# 4                          B00005N7O6
#
#                                             imageURL  \
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...
#
#                                      imageURLHighRes
# 0  [https://images-na.ssl-images-amazon.com/image...
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2  [https://images-na.ssl-images-amazon.com/image...
# 3  [https://images-na.ssl-images-amazon.com/image...
# 4  [https://images-na.ssl-images-amazon.com/image...

# %%
# drop duplicated items
df_meta = df_meta.iloc[df_meta['asin'].drop_duplicates().index]

# %%
df_meta.shape
# Out:
# (2320, 19)

# %% [markdown]
# asin is the ProductID

# %% [markdown]
# ## Collaborative Filtering

# %% [markdown]
# We used Collaborative Filtering for old users that had just purchased an item, giving them recommendations for similar items. Using the Surprise library we created a KNN Baseline model that was Item-Item, and gave us the Nearest Neighbors to the item purchased.

# %% [markdown]
# Installing Surprise library

# %%
# install surprise to build recommender in python
# !pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.1.tar.gz (11.8 MB)
#      |████████████████████████████████| 11.8 MB 9.9 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.1.0)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.21.6)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.15.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp37-cp37m-linux_x86_64.whl size=1630197 sha256=faea5f24a6f4845df2e1ece78d90bb7ae0d3b767c18e4f6ffbb109156d4577e4
#   Stored in directory: /root/.cache/pip/wheels/76/44/74/b498c42be47b2406bd27994e16c5188e337c657025ab400c1c
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.1

# %%
from surprise import KNNBaseline
from surprise import Reader
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise.model_selection import GridSearchCV

# %% [markdown]
# Converting the Pandas dataframe to a Dataset object for use with Surprise

# %%
reader = Reader(rating_scale=(1, 5))

data = Dataset.load_from_df(df[['Customer_ID', 'Product_ID', 'Rating']], reader)

# %% [markdown]
# Finding the optimal parameters using GridSearch 5 Fold Cross-Validation
#
# Baseline Options:
#
# *   Method: ALS (Alternating Least Squares)
# *   n_epochs: 5, 10
# *   reg_u: 10
# *   reg_i: 5
#
# Sim Options:
#
# *   Name: Cosine, Pearson_Baseline
# *   min_support: 1, 2, 3'
# *   user_based: False

# %%
ks = [10, 50, 100, 150, 200]

param_grid = {'bsl_options': {'method': ['als'], 'n_epochs': [5, 10], 
                              'reg_u': [10], 'reg_i': [5]},
              'k': ks,
              'sim_options': {'name': ['cosine', 'pearson_baseline'],
                              'min_support': [1, 2, 3],
                              'user_based': [False]}
              }
gs = GridSearchCV(KNNBaseline, param_grid, measures=['rmse'], cv=5)

gs.fit(data)
# Out:
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# Best Results for the Grid Search using RMSE as the score
#
# RMSE: 1.3118879603008418

# %%
# Best RMSE score
print("Best RMSE:", gs.best_score['rmse'])

# Combination of parameters that gave the best RMSE score
print("Best Parameters:", gs.best_params['rmse'])
# Out:
# Best RMSE: 1.3102081329536612
# Best Parameters: {'bsl_options': {'method': 'als', 'n_epochs': 10, 'reg_u': 10, 'reg_i': 5}, 'k': 50, 'sim_options': {'name': 'pearson_baseline', 'min_support': 3, 'user_based': False}}

# %% [markdown]
# All results from Cross Validation splits and parameters tested along their RMSE score

# %%
results_df = pd.DataFrame.from_dict(gs.cv_results)
results_df
# Out:
#     split0_test_rmse  split1_test_rmse  split2_test_rmse  split3_test_rmse  \
# 0           1.315770          1.318169          1.298835          1.314931
# 1           1.315171          1.318763          1.301441          1.313346
# 2           1.314785          1.318892          1.301443          1.311885
# 3           1.314310          1.318066          1.300734          1.312420
# 4           1.314310          1.318066          1.300734          1.312420
# 5           1.315068          1.317228          1.300147          1.312189
# 6           1.315795          1.318178          1.298854          1.314898
# 7           1.315210          1.318767          1.301456          1.313337
# 8           1.314810          1.318893          1.301444          1.311878
# 9           1.314310          1.318066          1.300734          1.312420
# 19       0.269534      0.004671        0.191804       0.083333
# 20       0.268937      0.006529        0.151829       0.005441
# 21       0.284923      0.004743        0.188273       0.074568
# 22       0.283706      0.007866        0.187330       0.079619
# 23       0.280505      0.002782        0.149653       0.003832
# 24       0.281578      0.004257        0.198943       0.080012
# 25       0.272982      0.008229        0.190493       0.083870
# 26       0.265879      0.008973        0.150126       0.004207
# 27       0.277834      0.004719        0.192267       0.082877
# 28       0.279709      0.007297        0.186837       0.074335
# 29       0.282313      0.008172        0.147917       0.002256
# 30       0.432324      0.005894        0.188301       0.074787
# 31       0.425593      0.008413        0.190320       0.072362
# 32       0.421908      0.009666        0.151777       0.002802
# 33       0.424672      0.013096        0.189904       0.076580
# 34       0.438603      0.013249        0.189915       0.078332
# 35       0.426438      0.013707        0.152896       0.002880
# 36       0.444461      0.007245        0.190917       0.075992
# 37       0.415228      0.006434        0.189768       0.079544
# 38       0.461010      0.086899        0.156245       0.006869
# 39       0.440052      0.008658        0.192704       0.079673
# 40       0.440128      0.010951        0.194226       0.074462
# 41       0.431174      0.006661        0.149517       0.003869
# 42       0.441386      0.010410        0.191440       0.076437
# 43       0.423243      0.006883        0.194845       0.080926
# 44       0.420580      0.005502        0.151100       0.005364
# 45       0.432540      0.009165        0.189071       0.073596
# 46       0.433076      0.005414        0.192182       0.073336
# 47       0.431702      0.004683        0.154077       0.005607
# 48       0.444575      0.006212        0.196815       0.081450
# 49       0.418019      0.008533        0.193040       0.079318
# 50       0.423597      0.007200        0.150756       0.000470
# 51       0.425540      0.012412        0.190452       0.077489
# 52       0.435022      0.004768        0.189930       0.078071
# 53       0.438027      0.004983        0.153051       0.005234
# 54       0.431759      0.009995        0.191566       0.076320
# 55       0.422452      0.006144        0.190701       0.073937
# 56       0.423204      0.002843        0.152023       0.002699
# 57       0.443378      0.012381        0.191213       0.076748
# 58       0.448476      0.010185        0.193481       0.078366
# 59       0.517799      0.100077        0.171555       0.041447
#
#                                                params  \
# 0   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 1   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 2   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 3   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 4   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 5   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 6   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 7   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 8   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 9   {'bsl_options': {'method': 'als', 'n_epochs': ...
# 10  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 11  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 12  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 13  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 14  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 15  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 16  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 17  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 18  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 19  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 20  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 21  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 22  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 23  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 24  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 25  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 26  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 27  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 28  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 29  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 30  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 31  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 32  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 33  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 34  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 35  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 36  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 37  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 38  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 39  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 40  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 41  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 42  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 43  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 44  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 45  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 46  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 47  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 48  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 49  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 50  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 51  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 52  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 53  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 54  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 55  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 56  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 57  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 58  {'bsl_options': {'method': 'als', 'n_epochs': ...
# 59  {'bsl_options': {'method': 'als', 'n_epochs': ...
#
#                                     param_bsl_options  param_k  \
# 0   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       10
# 1   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       10
# 2   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       10
# 3   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       10
# 4   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       10
# 5   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       10
# 6   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       50
# 7   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       50
# 8   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       50
# 9   {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       50
# 10  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       50
# 11  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...       50
# 12  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      100
# 13  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      100
# 14  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      100
# 15  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      100
# 16  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      100
# 17  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      100
# 18  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      150
# 19  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      150
# 20  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      150
# 21  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      150
# 22  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      150
# 23  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      150
# 24  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      200
# 25  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      200
# 26  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      200
# 27  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      200
# 28  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      200
# 29  {'method': 'als', 'n_epochs': 5, 'reg_u': 10, ...      200
# 30  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       10
# 31  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       10
# 32  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       10
# 33  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       10
# 34  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       10
# 35  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       10
# 36  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       50
# 37  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       50
# 38  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       50
# 39  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       50
# 40  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       50
# 41  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...       50
# 42  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      100
# 43  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      100
# 44  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      100
# 45  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      100
# 46  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      100
# 47  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      100
# 48  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      150
# 49  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      150
# 50  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      150
# 51  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      150
# 52  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      150
# 53  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      150
# 54  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      200
# 55  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      200
# 56  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      200
# 57  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      200
# 58  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      200
# 59  {'method': 'als', 'n_epochs': 10, 'reg_u': 10,...      200
#
#                                     param_sim_options
# 0   {'name': 'cosine', 'min_support': 1, 'user_bas...
# 1   {'name': 'cosine', 'min_support': 2, 'user_bas...
# 2   {'name': 'cosine', 'min_support': 3, 'user_bas...
# 3   {'name': 'pearson_baseline', 'min_support': 1,...
# 4   {'name': 'pearson_baseline', 'min_support': 2,...
# 5   {'name': 'pearson_baseline', 'min_support': 3,...
# 6   {'name': 'cosine', 'min_support': 1, 'user_bas...
# 7   {'name': 'cosine', 'min_support': 2, 'user_bas...
# 8   {'name': 'cosine', 'min_support': 3, 'user_bas...
# 9   {'name': 'pearson_baseline', 'min_support': 1,...
# 10  {'name': 'pearson_baseline', 'min_support': 2,...
# 11  {'name': 'pearson_baseline', 'min_support': 3,...
# 12  {'name': 'cosine', 'min_support': 1, 'user_bas...
# 13  {'name': 'cosine', 'min_support': 2, 'user_bas...
# 14  {'name': 'cosine', 'min_support': 3, 'user_bas...
# 15  {'name': 'pearson_baseline', 'min_support': 1,...
# 16  {'name': 'pearson_baseline', 'min_support': 2,...
# 17  {'name': 'pearson_baseline', 'min_support': 3,...
# 18  {'name': 'cosine', 'min_support': 1, 'user_bas...
# 19  {'name': 'cosine', 'min_support': 2, 'user_bas...
# 20  {'name': 'cosine', 'min_support': 3, 'user_bas...
# 21  {'name': 'pearson_baseline', 'min_support': 1,...
# 22  {'name': 'pearson_baseline', 'min_support': 2,...
# 23  {'name': 'pearson_baseline', 'min_support': 3,...
# 24  {'name': 'cosine', 'min_support': 1, 'user_bas...
# 25  {'name': 'cosine', 'min_support': 2, 'user_bas...
# 26  {'name': 'cosine', 'min_support': 3, 'user_bas...
# 27  {'name': 'pearson_baseline', 'min_support': 1,...
# 28  {'name': 'pearson_baseline', 'min_support': 2,...
# 29  {'name': 'pearson_baseline', 'min_support': 3,...
# 30  {'name': 'cosine', 'min_support': 1, 'user_bas...
# 31  {'name': 'cosine', 'min_support': 2, 'user_bas...
# 32  {'name': 'cosine', 'min_support': 3, 'user_bas...
# 33  {'name': 'pearson_baseline', 'min_support': 1,...
# 34  {'name': 'pearson_baseline', 'min_support': 2,...
# 35  {'name': 'pearson_baseline', 'min_support': 3,...
# 36  {'name': 'cosine', 'min_support': 1, 'user_bas...
# 37  {'name': 'cosine', 'min_support': 2, 'user_bas...
# 38  {'name': 'cosine', 'min_support': 3, 'user_bas...
# 39  {'name': 'pearson_baseline', 'min_support': 1,...
# 40  {'name': 'pearson_baseline', 'min_support': 2,...
# 41  {'name': 'pearson_baseline', 'min_support': 3,...
# 42  {'name': 'cosine', 'min_support': 1, 'user_bas...
# 43  {'name': 'cosine', 'min_support': 2, 'user_bas...
# 44  {'name': 'cosine', 'min_support': 3, 'user_bas...
# 45  {'name': 'pearson_baseline', 'min_support': 1,...
# 46  {'name': 'pearson_baseline', 'min_support': 2,...
# 47  {'name': 'pearson_baseline', 'min_support': 3,...
# 48  {'name': 'cosine', 'min_support': 1, 'user_bas...
# 49  {'name': 'cosine', 'min_support': 2, 'user_bas...
# 50  {'name': 'cosine', 'min_support': 3, 'user_bas...
# 51  {'name': 'pearson_baseline', 'min_support': 1,...
# 52  {'name': 'pearson_baseline', 'min_support': 2,...
# 53  {'name': 'pearson_baseline', 'min_support': 3,...
# 54  {'name': 'cosine', 'min_support': 1, 'user_bas...
# 55  {'name': 'cosine', 'min_support': 2, 'user_bas...
# 56  {'name': 'cosine', 'min_support': 3, 'user_bas...
# 57  {'name': 'pearson_baseline', 'min_support': 1,...
# 58  {'name': 'pearson_baseline', 'min_support': 2,...
# 59  {'name': 'pearson_baseline', 'min_support': 3,...

# %% [markdown]
# Creating and training a Baseline KNN model with ideal parameters and item-item

# %%
# Using Ideal Params to build the model
model = gs.best_estimator['rmse']

# Full ratings used to build trainset
trainset = data.build_full_trainset()

model.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# Get N nearest neighbors for an item
#
# This will give similar items to those purchased using the ID of the item and the number of similar items to return

# %%
def collaborative_recommendation(item_purchased, n=5):
  # Convert raw id (asin) to inner id
  inner_id = model.trainset.to_inner_iid(item_purchased)

  # Obtain inner ids of the n nearest neighbors of item_purchased
  neighbors = model.get_neighbors(inner_id, k=n)

  # Convert the inner ids of nearest neighbors to raw id (asin)
  neighbors = (model.trainset.to_raw_iid(inner_id) for inner_id in neighbors)
  ans = [i for i in neighbors]
  return ans

# %% [markdown]
# Example for item B00005N7O6 with top 5 similar items

# %%
item_id = "B00005N7O6"
n = 5
top_n = collaborative_recommendation(item_id)

print("Top", n, "Similar Items to", item_id)
for item in top_n:
  print(item)
# Out:
# Top 5 Similar Items to B00005N7O6
# B00007AWME
# B000UEI4JU
# B00005N7P0
# B00005N7OJ
# B00005N7Q1

# %% [markdown]
# ## Content-based

# %% [markdown]
# We modified the usual content-based recommendation system by overlapping the results with "also buy" and "also view", so that the recommendations are both similar to the product the user is searching for, and liked by other users.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics import jaccard_score

# %%
description = df_meta['description'].str[0]
category = df_meta['category'].str[0]
words = description + category + df_meta['brand'].astype(str)

# %% [markdown]
# Compute TF-IDF score

# %%
tfidf = TfidfVectorizer(stop_words='english')
words = words.fillna('')
tfidf_matrix = tfidf.fit_transform(words)

# %% [markdown]
# Compute cosine similarity score

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(df_meta.index, index=df_meta['asin']).drop_duplicates()

# %%
def content_based_recomendation(asin, n):

    idx = indices[asin]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:n+1]
    item_indices = [i[0] for i in sim_scores]

    rec = df_meta['asin'].iloc[item_indices]
    # also_buy = np.intersect1d(df_meta[df_meta['asin'] == asin]['also_buy'].iloc[0], list(rec))
    # also_view = np.intersect1d(df_meta[df_meta['asin'] == asin]['also_view'].iloc[0], list(rec))
    # return np.union1d(also_buy, also_view)
    ans = [i for i in rec]
    return ans

# %%
content_based_recomendation('B00005N7O6', 20)
# Out:
# ['B00007AWME',
#  'B00YQH9874',
#  'B015PRLQSW',
#  'B000ILZ6YQ',
#  'B000H4W7VO',
#  'B000SKWFL4',
#  'B00006AMTF',
#  'B0098QNZ22',
#  'B00005N7O4',
#  'B00007AXX3',
#  'B000UEI4JU',
#  'B000H4W7YG',
#  'B00006KBW2',
#  'B000089G4T',
#  'B00007AVYH',
#  'B00007B1AI',
#  'B00FW9D1ZU',
#  'B000HEVUJE',
#  'B00TGFD3M2',
#  'B00VVGRBI6']

# %% [markdown]
# ## Latent Factor

# %%
raw = pd.read_csv('Magazine_Subscriptions.csv', usecols=[i for i in range(3)], names=['Product_ID', 'Customer_ID', 'Rating'])
raw.drop_duplicates(inplace=True)
raw.columns = ['product_id','customer_id','Rating']
raw=raw[['customer_id','product_id','Rating']]

# %%
import surprise  #Scikit-Learn library for recommender systems. 
from surprise.model_selection import train_test_split

# %%
# when importing from a DF, you only need to specify the scale of the ratings.
reader = surprise.Reader(rating_scale=(1,5)) 
#into surprise:
data = surprise.Dataset.load_from_df(raw,reader)

# %%
trainset, testset = train_test_split(data)

# %% [markdown]
# Inherit from surpise library to modify fit and estimate to implement latent factor. Defined a function called get_recommendation which takes username and gives top N recommendation's based on Latent Factoring out of all items including the ones for which this user has never given rating

# %%
class MatrixFactorization(surprise.AlgoBase):
# Randomly initializes two Matrices and use Stochastic Gradient Descent(SGD) to be able to optimize the best factorization for ratings.
    def __init__(self,learning_rate,num_epochs,num_factors):
       # learning rate for Stochastic Gradient Descent
        self.alpha = learning_rate 
        self.num_epochs = num_epochs
        self.num_factors = num_factors # Number of Latent Factors

    # Takes a user name converts it to inner_uid gets top n inner_iid and converts to raw_iid(Item name) and returns them
    def get_recommendation(self,u,n=5):
      ans = []
      items = self.trainset.all_items()
      u_t = self.trainset.to_inner_uid(u)
      for i in items:
        ans.append((self.trainset.to_raw_iid(i),self.estimate(u_t,i)))
      ans.sort(key=lambda x: x[1], reverse=True)
      ans = ans[:n]
      res = []
      for i in ans:
        res.append(i[0])
      return res

    def fit(self,train):
        #randomly initialize user and item factors from a Gaussian
        P = np.random.normal(0,.1,(train.n_users,self.num_factors))
        Q = np.random.normal(0,.1,(train.n_items,self.num_factors))

        for epoch in range(self.num_epochs):
            for u,i,r_ui in train.all_ratings():
                residual = r_ui - np.dot(P[u],Q[i])
                # Update them at the same time so store in a temporary variable. 
                temp = P[u,:] 
                P[u,:] +=  self.alpha * residual * Q[i]
                Q[i,:] +=  self.alpha * residual * temp 
        self.P = P
        self.Q = Q
        self.trainset = train # Will be useful later on 

    def estimate(self,u,i):
        # Returns estimated rating for user u and item i.
        # Check to see if u and i are in the train set:

        if self.trainset.knows_user(u) and self.trainset.knows_item(i):
            nanCheck = np.dot(self.P[u],self.Q[i])
            if np.isnan(nanCheck):
                return self.trainset.global_mean
            else:
                return np.dot(self.P[u,:],self.Q[i,:])
        else:
          # if its not known we'll return the general average.
          # We wont reach this stage as we will be using contenet based for this scenario
            return self.trainset.global_mean

# %% [markdown]
# Below lines are used to get Train, Test RMSE for different combinations of hyperparameters which took more than 4 hours so stored the results in github repo(https://github.com/badri449/MMDS/blob/main/LatentFactor/Train_Parameters.txt)

# %%
# Uncomment below lines to train for different possible hyper parametrs
# Instead of for loop we can also use GridSearchCV to get best hyper parameters
"""
COLUMN_NAMES = ['LearningRate','Epochs',"NumFactors","Train RMSE","Test RMSE"]
result = pd.DataFrame(columns=COLUMN_NAMES)
for lr in [0.005,0.05,0.1,0.5]:
    for epochs in [10,15,20,25,30,40,45,50,60]:
        for num_factors in [2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,50]:
            Alg1 = MatrixFactorization(learning_rate=lr,num_epochs=epochs,num_factors=num_factors)
            print("lr: ",lr," epoch: ",epochs,"num: ",num_factors)
            Alg1.fit(trainset)
            prediction = Alg1.test(trainset.build_testset())
            train_error = surprise.accuracy.rmse(prediction,verbose=True)
            prediction = Alg1.test(testset)
            test_error = surprise.accuracy.rmse(prediction,verbose=True)
            cur = [lr,epochs,num_factors,train_error,test_error]
            result_length = len(result)
            result.loc[result_length] = cur
"""
"""
gs = surprise.model_selection.GridSearchCV(MatrixFactorization, param_grid={'learning_rate':[0.005,0.05,0.1,0.5],
                                                                            'num_epochs':[10,15,20,25,30,40,45,50,60],
                                                                            'num_factors':[2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,50]},measures=['rmse', 'mae'], cv=2)
gs.fit(data) # Training on entire dataset
print('rmse: ',gs.best_score['rmse'],'mae: ',gs.best_score['mae'])
best_params = gs.best_params['rmse']
print('rmse: ',gs.best_params['rmse'],'mae: ',gs.best_params['mae'])
"""
# Uncoment either of the above if you want to train a different combinations of hyper parameters
# Out:
# "\ngs = surprise.model_selection.GridSearchCV(MatrixFactorization, param_grid={'learning_rate':[0.005,0.05,0.1,0.5],\n                                                                            'num_epochs':[10,15,20,25,30,40,45,50,60],\n                                                                            'num_factors':[2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,50]},measures=['rmse', 'mae'], cv=2)\ngs.fit(data) # Training on entire dataset\nprint('rmse: ',gs.best_score['rmse'],'mae: ',gs.best_score['mae'])\nbest_params = gs.best_params['rmse']\nprint('rmse: ',gs.best_params['rmse'],'mae: ',gs.best_params['mae'])\n"

# %% [markdown]
# Load the results from github repo

# %%
url = 'https://github.com/badri449/MMDS/raw/main/LatentFactor/Train_Parameters.txt'
result = pd.read_csv(url,index_col=False)
result = result.drop(['index'], axis = 1)
result.columns = ['LearningRate', 'Epochs', 'LatentFactors', 'TrainRMSE','TestRMSE']

# %%
# Sort the results based on Train RMSE 
result.sort_values(by=['TrainRMSE'])
# Out:
#      LearningRate  Epochs  LatentFactors  TrainRMSE  TestRMSE
# 143         0.005    60.0           50.0   0.234026  1.982881
# 142         0.005    60.0           40.0   0.270494  1.972494
# 141         0.005    60.0           35.0   0.292634  1.967087
# 140         0.005    60.0           30.0   0.318007  1.953089
# 127         0.005    50.0           50.0   0.343207  1.981028
# ..            ...     ...            ...        ...       ...
# 4           0.005    10.0            6.0   2.590315  2.033179
# 3           0.005    10.0            5.0   2.649409  2.054577
# 2           0.005    10.0            4.0   2.661590  2.007664
# 1           0.005    10.0            3.0   2.716431  2.044642
# 0           0.005    10.0            2.0   2.832111  2.055095
#
# [576 rows x 5 columns]

# %%
# Sort the results based on Test RMSE 
result.sort_values(by=['TestRMSE'])
# Out:
#      LearningRate  Epochs  LatentFactors  TrainRMSE  TestRMSE
# 208         0.050    30.0            2.0   1.392116  1.412927
# 400         0.100    50.0            2.0   1.399411  1.412991
# 160         0.050    15.0            2.0   1.398663  1.413018
# 575         0.500    60.0           50.0   1.416786  1.413019
# 479         0.500    20.0           50.0   1.416786  1.413019
# ..            ...     ...            ...        ...       ...
# 8           0.005    10.0           10.0   2.496395  2.036969
# 11          0.005    10.0           25.0   2.319462  2.043628
# 1           0.005    10.0            3.0   2.716431  2.044642
# 3           0.005    10.0            5.0   2.649409  2.054577
# 0           0.005    10.0            2.0   2.832111  2.055095
#
# [576 rows x 5 columns]

# %% [markdown]
# From the above two sorts we can see even if the train RMSE is 0.23 we got Test Rmse as 1.98 it means overfitting as can be expected as latent factors are 50.<br>
# So better to choose best hyper parameters based on Test RMSE which are:
# *   Learning Rate: 0.050
# *   Epochs: 30
# *   NumFactors: 2
# <br>
# Test RMSE is 1.412927 Train RMSE is 1.392116.

# %%
bestVersion = MatrixFactorization(learning_rate=0.050,num_epochs=30,num_factors=2)

# %% [markdown]
#  Used k-fold cross validation to evaluate the best model.

# %%
kSplit = surprise.model_selection.KFold(n_splits=10,shuffle=True)
for train,test in kSplit.split(data):
    bestVersion.fit(train)
    prediction = bestVersion.test(test)
    surprise.accuracy.rmse(prediction,verbose=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: overflow encountered in multiply
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in add
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning: overflow encountered in multiply
# RMSE: 1.4245
# RMSE: 1.4228
# RMSE: 1.4187
# RMSE: 1.3840
# RMSE: 1.4163
# RMSE: 1.4158
# RMSE: 1.4360
# RMSE: 1.4216
# RMSE: 1.4318
# RMSE: 1.4208

# %% [markdown]
# The above results are consistant with what we got while training

# %% [markdown]
# Now train the best version(optimal hyper parameters) on the entire data set

# %%
bestVersion = MatrixFactorization(learning_rate=0.050,num_epochs=30,num_factors=2)
data1 = data.build_full_trainset()
bestVersion.fit(data1) # Train on full data set
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning: overflow encountered in multiply
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: overflow encountered in multiply
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in add

# %%
def latent_recommendation(user_name,N=5):
  return bestVersion.get_recommendation(user_name,N)

# %% [markdown]
# Test latent recommendation function

# %%
latent_recommendation("AQJDVLLWELFJ1",9)
# Out:
# ['B00005N7P0',
#  'B00005N7OJ',
#  'B00005N7Q1',
#  'B00005N7OD',
#  'B00005N7PS',
#  'B00005N7OU',
#  'B00005N7QC',
#  'B00005N7PA',
#  'B00005N7OV']

# %%
# create an array of unique users - Yuqi
unique_users = df['Customer_ID'].unique()

# %% [markdown]
# This Function is the Final result

# %%
# return a list of N top recommendations
def get_recomendation(user_name,N=5,item_id=None):
  if user_name in unique_users:
    if item_id is not None:
      # Old user purchased an item
      return collaborative_recommendation(item_id,N)
    else:
      # Old user just browsing
      return latent_recommendation(user_name,N)
    # New user browsing
  return content_based_recomendation(item_id,N)

# %% [markdown]
# Test for different scenarios

# %%
# New User browsing
get_recomendation('xx',5,'B00005N7O6')
# Out:
# ['B00007AWME', 'B00YQH9874', 'B015PRLQSW', 'B000ILZ6YQ', 'B000H4W7VO']

# %%
# Old user Browsing
get_recomendation("AQJDVLLWELFJ1",5)
# Out:
# ['B00005N7P0', 'B00005N7OJ', 'B00005N7Q1', 'B00005N7OD', 'B00005N7PS']

# %%
# Old user Purchased an item
get_recomendation("AQJDVLLWELFJ1",3,"B00005N7O6")
# Out:
# ['B00007AWME', 'B000UEI4JU', 'B00005N7P0']
